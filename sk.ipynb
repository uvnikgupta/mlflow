# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedShuffleSplit, KFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import plot_roc_curve, roc_auc_score, confusion_matrix, classification_report, f1_score
from sklearn.preprocessing import StandardScaler

from load_data import DataLoader
from train_logreg_model import ModelTrainer

# %%
dl = DataLoader()
dl.load_data('dataset/creditcard.csv', ['Class'], ['Time'])

x_train, y_train = dl.x_train, dl.y_train.reshape(-1,)
x_test, y_test = dl.x_test, dl.y_test.reshape(-1,)
x_val, y_val = dl.x_val, dl.y_val.reshape(-1,)

# %%
model_trainer = ModelTrainer(x_train, y_train)
logs = model_trainer.train()
# Out:
# Training for weight 1, fold 1
# Training for weight 1, fold 2
# Training for weight 1, fold 3
# Training for weight 1, fold 4
# Training for weight 1, fold 5
# Training for weight 5, fold 1
# Training for weight 5, fold 2
# Training for weight 5, fold 3
# Training for weight 5, fold 4
# Training for weight 5, fold 5
# Training for weight 10, fold 1
# Training for weight 10, fold 2
# Training for weight 10, fold 3
# Training for weight 10, fold 4
# Training for weight 10, fold 5
# Training for weight 15, fold 1
# Training for weight 15, fold 2
# Training for weight 15, fold 3
# Training for weight 15, fold 4
# Training for weight 15, fold 5

# %%
logs
# Out:
# [{'Weight': 1,
#   'Fold': 1,
#   'F1_score': 0.7027027027027026,
#   'Precision': 0.8387096774193549,
#   'Recall': 0.6046511627906976,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 1}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 1,
#   'Fold': 2,
#   'F1_score': 0.8405797101449276,
#   'Precision': 0.9354838709677419,
#   'Recall': 0.7631578947368421,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 1}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 1,
#   'Fold': 3,
#   'F1_score': 0.7551020408163265,
#   'Precision': 0.9024390243902439,
#   'Recall': 0.6491228070175439,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 1}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 1,
#   'Fold': 4,
#   'F1_score': 0.735632183908046,
#   'Precision': 0.8421052631578947,
#   'Recall': 0.6530612244897959,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 1}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 1,
#   'Fold': 5,
#   'F1_score': 0.8031496062992126,
#   'Precision': 0.8947368421052632,
#   'Recall': 0.7285714285714285,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 1}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 5,
#   'Fold': 1,
#   'F1_score': 0.7045454545454545,
#   'Precision': 0.6888888888888889,
#   'Recall': 0.7209302325581395,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 5}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 5,
#   'Fold': 2,
#   'F1_score': 0.8456375838926175,
#   'Precision': 0.863013698630137,
#   'Recall': 0.8289473684210527,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 5}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 5,
#   'Fold': 3,
#   'F1_score': 0.7931034482758621,
#   'Precision': 0.7796610169491526,
#   'Recall': 0.8070175438596491,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 5}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 5,
#   'Fold': 4,
#   'F1_score': 0.7920792079207921,
#   'Precision': 0.7692307692307693,
#   'Recall': 0.8163265306122449,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 5}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 5,
#   'Fold': 5,
#   'F1_score': 0.8260869565217392,
#   'Precision': 0.8382352941176471,
#   'Recall': 0.8142857142857143,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 5}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 10,
#   'Fold': 1,
#   'F1_score': 0.6808510638297872,
#   'Precision': 0.6274509803921569,
#   'Recall': 0.7441860465116279,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 10}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 10,
#   'Fold': 2,
#   'F1_score': 0.8258064516129032,
#   'Precision': 0.810126582278481,
#   'Recall': 0.8421052631578947,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 10}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 10,
#   'Fold': 3,
#   'F1_score': 0.7768595041322315,
#   'Precision': 0.734375,
#   'Recall': 0.8245614035087719,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 10}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 10,
#   'Fold': 4,
#   'F1_score': 0.7547169811320754,
#   'Precision': 0.7017543859649122,
#   'Recall': 0.8163265306122449,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 10}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 10,
#   'Fold': 5,
#   'F1_score': 0.8194444444444444,
#   'Precision': 0.7972972972972973,
#   'Recall': 0.8428571428571429,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 10}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 15,
#   'Fold': 1,
#   'F1_score': 0.6666666666666666,
#   'Precision': 0.6037735849056604,
#   'Recall': 0.7441860465116279,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 15}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 15,
#   'Fold': 2,
#   'F1_score': 0.8,
#   'Precision': 0.7619047619047619,
#   'Recall': 0.8421052631578947,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 15}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 15,
#   'Fold': 3,
#   'F1_score': 0.734375,
#   'Precision': 0.6619718309859155,
#   'Recall': 0.8245614035087719,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 15}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 15,
#   'Fold': 4,
#   'F1_score': 0.7241379310344828,
#   'Precision': 0.6268656716417911,
#   'Recall': 0.8571428571428571,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 15}, max_iter=400, random_state=42,
#                      solver='newton-cg')},
#  {'Weight': 15,
#   'Fold': 5,
#   'F1_score': 0.8027210884353742,
#   'Precision': 0.7662337662337663,
#   'Recall': 0.8428571428571429,
#   'Model': LogisticRegression(class_weight={0: 1, 1: 15}, max_iter=400, random_state=42,
#                      solver='newton-cg')}]
